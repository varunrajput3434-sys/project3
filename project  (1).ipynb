# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\VARUN\Downloads\housing_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Unnamed: 0     1460.0     729.500000    421.610009      0.0     364.75
# LotFrontage    1460.0      57.623288     34.664304      0.0      42.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1460.0     103.117123    180.731373      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# ...

# %%
data.describe(include='object')
# Out:
#        MSSubClass MSZoning Street Alley LotShape LandContour Utilities  \
# count        1460     1460   1460    91     1460        1460      1460
# unique         15        5      2     2        4           4         2
# top          SC20       RL   Pave  Grvl      Reg         Lvl    AllPub
# freq          536     1151   1454    50      925        1311      1459
#
#        LotConfig LandSlope Neighborhood  ... GarageFinish GarageQual  \
# count       1460      1460         1460  ...         1460       1460
# unique         5         3           25  ...            4          6
# top       Inside       Gtl        NAmes  ...          Unf         TA
# freq        1052      1382          225  ...          605       1311
#
#        GarageCond PavedDrive PoolQC Fence MiscFeature MoSold SaleType  \
# count        1460       1460   1460  1460        1460   1460     1460
# unique          6          3      4     5           5     12        9
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
sns.histplot("lotArea")
# Out:
# <Axes: ylabel='Count'>

# %%
sns.pairplot(x_vars=['OverallQual','GrLivArea','GarageArea','TotalBsmtSF'], y_vars=['SalePrice'], data=data)

# %% [markdown]
# ## Univariate and Bivariate Analysis

# %%
sns.histplot(data['SalePrice'])
plt.show()

# %%
sns.distplot(data['SalePrice'])
print('Skewness: ',data['SalePrice'].skew())
print('Kurtosis: ',data['SalePrice'].kurt())
plt.show()
# Out:
# Skewness:  1.8828757597682129
# Kurtosis:  6.536281860064529

# %%
sns.boxplot(data['SalePrice'])
plt.show()

# %%
plt.figure(figsize=(15,13))
plt.subplot(3,1,1)
sns.boxplot(x=data['OverallQual'],y=data['SalePrice'])
plt.subplot(3,1,2)
sns.boxplot(x=data['GarageType'],y=data['SalePrice'])
plt.subplot(3,1,3)
sns.boxplot(x=data['Electrical'],y=data['SalePrice'])

plt.show()

# %% [markdown]
# # Performing statisticsl test on SalePrice on the basis of overall quality

# %%
price_a = data[data['OverallQual']<=5]['SalePrice']
price_b = data[data['OverallQual']>5]['SalePrice']

# %%
from statsmodels.stats.weightstats import ztest

# %%
z_score,p_val = ztest(price_a,price_b)
if p_val>0.05:
    print('Ho: is True (There is no difference in price on the basis of Overall Qual)')
else:
    print('Ha: is True (The sales price different because of overall Qual)')
# Out:
# Ha: is True (The sales price different because of overall Qual)

# %%
p_val
# Out:
# np.float64(4.6976629506204295e-127)

# %%
z_score
# Out:
# np.float64(-23.978180675989137)

# %%
data['GarageType'].value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# No          81
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
data['GarageCars'].value_counts()
# Out:
# GarageCars
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: count, dtype: int64

# %%
from scipy.stats import chi2_contingency

# %%
observed = pd.crosstab(data['GarageCars'],data['GarageType'])

# %%
chi,p_val,dof,expected = chi2_contingency(observed)

# %%
expected
# Out:
# array([[3.32876712e-01, 4.82671233e+01, 1.05410959e+00, 4.88219178e+00,
#         4.99315068e-01, 2.14705479e+01, 4.49383562e+00],
#        [1.51643836e+00, 2.19883562e+02, 4.80205479e+00, 2.22410959e+01,
#         2.27465753e+00, 9.78102740e+01, 2.04719178e+01],
#        [3.38630137e+00, 4.91013699e+02, 1.07232877e+01, 4.96657534e+01,
#         5.07945205e+00, 2.18416438e+02, 4.57150685e+01],
#        [7.43835616e-01, 1.07856164e+02, 2.35547945e+00, 1.09095890e+01,
#         1.11575342e+00, 4.79773973e+01, 1.00417808e+01],
#        [2.05479452e-02, 2.97945205e+00, 6.50684932e-02, 3.01369863e-01,
#         3.08219178e-02, 1.32534247e+00, 2.77397260e-01]])

# %%
if p_val>0.05:
    print('Ho: is True (Garage cars is independent of garage type)')
else:
    print('Ha: is True (Garage cars is dependent of garage type)')
# Out:
# Ha: is True (Garage cars is dependent of garage type)

# %%
observed
# Out:
# GarageType  2Types  Attchd  Basment  BuiltIn  CarPort  Detchd  No
# GarageCars
# 0                0       0        0        0        0       0  81
# 1                0     171        8        8        3     179   0
# 2                1     560       11       50        6     196   0
# 3                4     138        0       30        0       9   0
# 4                1       1        0        0        0       3   0

# %%
p_val
# Out:
# np.float64(0.0)

# %% [markdown]
# ## Missing Value treatment

# %%
((data.isnull().sum()/data.isnull().count())*100).sort_values(ascending=False)
# Out:
# Alley            93.767123
# MasVnrType       59.726027
# GarageYrBlt       5.547945
# Electrical        0.068493
# Unnamed: 0        0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
data[data['Electrical'].isnull()]
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1379        1379       SC80       RL           73     9735   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 1379      Reg         Lvl    AllPub  ...        0     No    No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1379       0    May   2008        WD         Normal     167500
#
# [1 rows x 81 columns]

# %%
data['Electrical'].mode()
# Out:
# 0    SBrkr
# Name: Electrical, dtype: object

# %%
garage_mis = data[data['GarageType'].isnull()]

# %%
garage_mis['GarageCars'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
garage_mis.groupby(['GarageCars'])['GarageArea'].mean()
# Out:
# Series([], Name: GarageArea, dtype: float64)

# %%
data['GarageType'] = np.where(data['GarageCars']==0,'NoGarage',data['GarageType'])

# %%
data[data['GarageType'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
sns.countplot(x='GarageType', data = data[data['GarageCars']==1])
plt.show()

# %%
data.groupby(['GarageType','GarageCars'])['GarageArea'].median()
# Out:
# GarageType  GarageCars
# 2Types      2              750.0
#             3              825.0
#             4             1356.0
# Attchd      1              288.0
#             2              504.0
#             3              822.0
#             4              784.0
# Basment     1              338.0
#             2              525.0
# BuiltIn     1              292.5
#             2              474.0
#             3              766.0
# CarPort     1              294.0
#             2              489.0
# Detchd      1              275.0
#             2              528.0
#             3              840.0
#             4              864.0
# NoGarage    0                0.0
# Name: GarageArea, dtype: float64

# %%
data['GarageType'] = np.where(data['GarageType'].isnull(),'Detchd',data['GarageType'])

# %%
data[data['GarageType'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
data['GarageType'].value_counts()
# Out:
# GarageType
# Attchd      870
# Detchd      387
# BuiltIn      88
# NoGarage     81
# Basment      19
# CarPort       9
# 2Types        6
# Name: count, dtype: int64

# %%
data.drop(columns=['MiscFeature','Fence'], inplace=True)

# %%
((data.isnull().sum()/data.isnull().count())*100).sort_values(ascending=False)
# Out:
# Alley            93.767123
# MasVnrType       59.726027
# GarageYrBlt       5.547945
# Electrical        0.068493
# MSZoning          0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 79, dtype: float64

# %% [markdown]
# ## Outlier treatment

# %%
sns.scatterplot(x='SalePrice',y='TotalBsmtSF', data=data)
# Out:
# <Axes: xlabel='SalePrice', ylabel='TotalBsmtSF'>

# %%
sns.boxplot(data['TotalBsmtSF'])
# Out:
# <Axes: ylabel='TotalBsmtSF'>

# %%
data[data['TotalBsmtSF']>5000]
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1298        1298       SC60       RL          313    63887   Pave   NaN
#
#      LotShape LandContour Utilities  ... 3SsnPorch ScreenPorch PoolArea  \
# 1298      IR3         Bnk    AllPub  ...         0           0      480
#
#      PoolQC MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298     Gd       0    Jan   2008       New        Partial     160000
#
# [1 rows x 79 columns]

# %%
sns.scatterplot(x='SalePrice',y='TotalBsmtSF', data=data)
# Out:
# <Axes: xlabel='SalePrice', ylabel='TotalBsmtSF'>

# %%
sns.boxplot(data['TotalBsmtSF'])
# Out:
# <Axes: ylabel='TotalBsmtSF'>

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,1,1)
sns.boxplot(data['GrLivArea'])
plt.subplot(3,1,2)
sns.boxplot(data['GarageArea'])
plt.subplot(3,1,3)
sns.boxplot(data['SalePrice'])
# Out:
# <Axes: ylabel='SalePrice'>

# %%
sns.scatterplot(x='SalePrice',y='GrLivArea', data=data)
# Out:
# <Axes: xlabel='SalePrice', ylabel='GrLivArea'>

# %%
data[data['SalePrice']>700000]
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 691          691       SC60       RL          104    21535   Pave   NaN
# 1182        1182       SC60       RL          160    15623   Pave   NaN
#
#      LotShape LandContour Utilities  ... 3SsnPorch ScreenPorch PoolArea  \
# 691       IR1         Lvl    AllPub  ...         0           0        0
# 1182      IR1         Lvl    AllPub  ...         0           0      555
#
#      PoolQC MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691      No       0    Jan   2007        WD         Normal     755000
# 1182     Ex       0    Jul   2007        WD        Abnorml     745000
#
# [2 rows x 79 columns]

# %%
data[data['GrLivArea']>4000]
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 523          523       SC60       RL          130    40094   Pave   NaN
# 691          691       SC60       RL          104    21535   Pave   NaN
# 1182        1182       SC60       RL          160    15623   Pave   NaN
# 1298        1298       SC60       RL          313    63887   Pave   NaN
#
#      LotShape LandContour Utilities  ... 3SsnPorch ScreenPorch PoolArea  \
# 523       IR1         Bnk    AllPub  ...         0           0        0
# 691       IR1         Lvl    AllPub  ...         0           0        0
# 1182      IR1         Lvl    AllPub  ...         0           0      555
# 1298      IR3         Bnk    AllPub  ...         0           0      480
#
#      PoolQC MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 523      No       0    Oct   2007       New        Partial     184750
# 691      No       0    Jan   2007        WD         Normal     755000
# ...

# %%
data.drop(index=[500], inplace=True)

# %%
sns.scatterplot(x='SalePrice',y='GarageArea', data=data)
# Out:
# <Axes: xlabel='SalePrice', ylabel='GarageArea'>

# %%
data.describe().T
# Out:
#                 count           mean           std      min       25%  \
# Unnamed: 0     1459.0     729.657300    421.711711      0.0     364.5
# LotFrontage    1459.0      57.648389     34.662914      0.0      42.0
# LotArea        1459.0   10522.740918   9982.129082   1300.0    7559.0
# OverallQual    1459.0       6.099383      1.383468      1.0       5.0
# OverallCond    1459.0       5.575737      1.113079      1.0       5.0
# YearBuilt      1459.0    1971.266621     30.213226   1872.0    1954.0
# YearRemodAdd   1459.0    1984.873886     20.650146   1950.0    1967.0
# MasVnrArea     1459.0     102.992461    180.730538      0.0       0.0
# BsmtFinSF1     1459.0     443.699794    456.248699      0.0       0.0
# BsmtFinSF2     1459.0      46.581220    161.369977      0.0       0.0
# BsmtUnfSF      1459.0     567.412611    441.969453      0.0     223.0
# TotalBsmtSF    1459.0    1057.693626    438.739565      0.0     796.0
# ...

# %% [markdown]
# ## Feature Selection

# %%
data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... 3SsnPorch ScreenPorch PoolArea PoolQC MiscVal  \
# 0         Lvl    AllPub  ...         0           0        0     No       0
# 1         Lvl    AllPub  ...         0           0        0     No       0
# 2         Lvl    AllPub  ...         0           0        0     No       0
# 3         Lvl    AllPub  ...         0           0        0     No       0
# 4         Lvl    AllPub  ...         0           0        0     No       0
#
# ...

# %%
data.shape
# Out:
# (1459, 79)

# %% [markdown]
# ## Feature Engineering

# %%
data.dtypes
# Out:
# Unnamed: 0        int64
# MSSubClass       object
# MSZoning         object
# LotFrontage       int64
# LotArea           int64
#                   ...
# MoSold           object
# YrSold            int64
# SaleType         object
# SaleCondition    object
# SalePrice         int64
# Length: 79, dtype: object

# %%
data=pd.get_dummies(data, drop_first=True)

# %%
data.head()
# Out:
#    Unnamed: 0  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0           0           65     8450            7            5       2003
# 1           1           80     9600            6            8       1976
# 2           2           68    11250            7            5       2001
# 3           3           60     9550            7            5       1915
# 4           4           84    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLI  \
# 0          2003         196         706           0  ...           False
# 1          1976           0         978           0  ...           False
# 2          2002         162         486           0  ...           False
# 3          1970           0         216           0  ...           False
# 4          2000         350         655           0  ...           False
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %% [markdown]
# # APPLYING ML MODELS ON DATASET

# %% [raw]
# ## Train Test Split

# %%
x = data.drop(columns=['SalePrice'])
y = data['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=1)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1167, 272) (292, 272) (1167,) (292,)

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model_lr = LinearRegression()

# %%
    # y = bo + b1x1 + b2x2....b16x16

# %% [markdown]
# ## STATISTICAL MODEL

# %%
import statsmodels.api as sm
model_stats = sm.OLS(y,x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[163], line 2
#       1 import statsmodels.api as sm
# ----> 2 model_stats = sm.OLS(y,x)
#
# File ~\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File ~\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
# ...

# %%
result = model_stats.fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 result = model_stats.fit()
#
# NameError: name 'model_stats' is not defined

# %%
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 print(result.summary())
#
# NameError: name 'result' is not defined

# %%
# Durbin Watson Test
# Test For Autocorrelation 
# 2 --> No Autocorrelation (Homoscadestic)
# 0-2 --> Pos Autocorrelation (Hetroscadestic)
# 2-4 --> Neg Autocorrelation (Hetroscadestic)

# %%
# Jarque-bera test and Omnibus Test
# p-val <0.05 or p-val>0.95
# residual are normally distributed

# %% [markdown]
# ## Check the model for Overfitting

# %%
## Ridge regression

# %%
from sklearn.linear_model import Ridge

# %%
model_ridge = Ridge(alpha=10)

# %% [markdown]
# ## kMeanscluster

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        ...
#        'SaleType_ConLI', 'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth',
#        'SaleType_WD', 'SaleCondition_AdjLand', 'SaleCondition_Alloca',
#        'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=273)
